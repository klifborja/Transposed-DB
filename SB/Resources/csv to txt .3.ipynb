# %%
import csv
import os
import pandas as pd
from sys import argv
from datetime import date, timedelta, datetime

# %%
ifile = "PaperCutDailyLogs.csv"
ofile = "papercut.csv"

# %%
#if len(argv) > 2:
#	ifile = argv[1]
#	ofile = argv[2]
 #ufile = argv[3]

# %%
csv_df = pd.read_csv(ifile)
csv_df
# Out:
#              Date Username    Full Name  User Office  User Department  Email  \
# 0    6/4/20 16:02   borjas  Shaun Borja          NaN              NaN    NaN
# 1   5/29/20 16:30   borjas  Shaun Borja          NaN              NaN    NaN
# 2    6/4/20 12:03   borjas  Shaun Borja          NaN              NaN    NaN
# 3    6/4/20 13:47   borjas  Shaun Borja          NaN              NaN    NaN
# 4    6/4/20 13:48   borjas  Shaun Borja          NaN              NaN    NaN
# 5    6/4/20 13:56   borjas  Shaun Borja          NaN              NaN    NaN
# 6    6/4/20 14:15   borjas  Shaun Borja          NaN              NaN    NaN
# 7    6/4/20 15:07   borjas  Shaun Borja          NaN              NaN    NaN
# 8    6/4/20 15:05   borjas  Shaun Borja          NaN              NaN    NaN
# 9    6/4/20 16:04   borjas  Shaun Borja          NaN              NaN    NaN
# 10   6/4/20 16:05   borjas  Shaun Borja          NaN              NaN    NaN
# ...

# %%
pc_df = csv_df[["Shared Account Name", "Date", "Shared Account Code", "Total Printed Pages", "Cost", "Total Color Pages", "Copies"]]
pc_df.head()
# Out:
#      Shared Account Name           Date  Shared Account Code  \
# 0      BNMV2 OPTOMETRY 1   6/4/20 16:02           45011180.0
# 1  Rancho Bernardo\22450  5/29/20 16:30               3587.0
# 2  Rancho Bernardo\22450   6/4/20 12:03               3587.0
# 3  Rancho Bernardo\22450   6/4/20 13:47               3587.0
# 4  Rancho Bernardo\22450   6/4/20 13:48               3587.0
#
#    Total Printed Pages  Cost  Total Color Pages  Copies
# 0                    4  1.20                  4       1
# 1                    1  0.00                  1       1
# 2                    1  0.00                  0       1
# 3                    1  0.15                  0       1
# 4                    4  0.00                  4       1

# %%
#df_t = pc_df.T
#df_t

# %%
#reader_list = list(pc_df)
#reader_list.pop(0)
#reader_list

# %%
outfile = open(ofile, "w", newline='')

# %%
for line in reader_list:
    Header = line [0]
    AccountName = line[1]
    Date = line[2]
    TotalPrintedPages = line[3]
    #CostEach = str(float(Cost) % int(TotalPrintedPages))
    Cost = line[4]
    TotalColorPages = line[5]
    #TotalBWPages = str(int(TotalPrintedPages) - int(TotalColorPages))
    Copies = line[6]
    #d = datetime.strptime(Date,'%m%d%y %H:%M')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-c0b1b8ee720d> in <module>
#       5     TotalPrintedPages = line[3]
#       6     #CostEach = str(float(Cost) % int(TotalPrintedPages))
# ----> 7     Cost = line[4]
#       8     TotalColorPages = line[5]
#       9     #TotalBWPages = str(int(TotalPrintedPages) - int(TotalColorPages))
#
# IndexError: string index out of range
