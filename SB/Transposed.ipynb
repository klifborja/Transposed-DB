# %%
import numpy as np
import pandas as pd

# %%
import sqlalchemy
from sqlalchemy import create_engine, func

# %%
csv_file = "Resources/PaperCutDailyLogs.csv"
csv_df = pd.read_csv(csv_file)
csv_df
# Out:
#              Date Username    Full Name  User Office  User Department  Email  \
# 0    6/4/20 16:02   borjas  Shaun Borja          NaN              NaN    NaN
# 1   5/29/20 16:30   borjas  Shaun Borja          NaN              NaN    NaN
# 2    6/4/20 12:03   borjas  Shaun Borja          NaN              NaN    NaN
# 3    6/4/20 13:47   borjas  Shaun Borja          NaN              NaN    NaN
# 4    6/4/20 13:48   borjas  Shaun Borja          NaN              NaN    NaN
# 5    6/4/20 13:56   borjas  Shaun Borja          NaN              NaN    NaN
# 6    6/4/20 14:15   borjas  Shaun Borja          NaN              NaN    NaN
# 7    6/4/20 15:07   borjas  Shaun Borja          NaN              NaN    NaN
# 8    6/4/20 15:05   borjas  Shaun Borja          NaN              NaN    NaN
# 9    6/4/20 16:04   borjas  Shaun Borja          NaN              NaN    NaN
# 10   6/4/20 16:05   borjas  Shaun Borja          NaN              NaN    NaN
# ...

# %%
csv_df_transposed = csv_df.T
csv_df_transposed
# Out:
#                                               0                       1  \
# Date                               6/4/20 16:02           5/29/20 16:30
# Username                                 borjas                  borjas
# Full Name                           Shaun Borja             Shaun Borja
# User Office                                 NaN                     NaN
# User Department                             NaN                     NaN
# Email                                       NaN                     NaN
# Primary Card Number                       92102                   92102
# Charged Account                          SHARED                  SHARED
# Shared Account Name           BNMV2 OPTOMETRY 1   Rancho Bernardo\22450
# Shared Account Code                 4.50112e+07                    3587
# Shared Account Parent Name    BNMV2 OPTOMETRY 1         Rancho Bernardo
# Shared Account Parent Code          4.50112e+07                     NaN
# ...

# %%
csv_df.dtypes
# Out:
# Date                            object
# Username                        object
# Full Name                       object
# User Office                    float64
# User Department                float64
# Email                          float64
# Primary Card Number              int64
# Charged Account                 object
# Shared Account Name             object
# Shared Account Code            float64
# Shared Account Parent Name      object
# Shared Account Parent Code     float64
# Shared Account Sub Name        float64
# Shared Account Sub Code        float64
# Printer Server                  object
# Printer Name                    object
# Physical Printer Identifier     object
# Printer Type/Model              object
# Printer Serial Number           object
# Document                        object
# Use Type                        object
# Total Printed Pages              int64
# Total Color Pages                int64
# Color Pages Estimated           object
# ...
